# %% [markdown]
# <a href="https://colab.research.google.com/github/DreamWalker1412/Colab/blob/main/CADA_VAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #查看GPU信息

# %%
# !nvidia-smi
# Out:
# Wed Jun 17 19:27:19 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     7W /  75W |      0MiB /  7611MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# #查看CPU信息

# %%
# !cat /proc/cpuinfo

# %% [markdown]
# #查看内存信息

# %%
# !cat /proc/meminfo

# %% [markdown]
# #从Dropbox获取数据集和代码

# %%
# !wget -c https://www.dropbox.com/sh/oxk6087vnsazr60/AABgsh2rrC79aWDaXeC-4VXIa?dl=0 -O CADA_VAE.zip
# !unzip CADA_VAE.zip
# Out:
# --2020-06-17 19:27:40--  https://www.dropbox.com/sh/oxk6087vnsazr60/AABgsh2rrC79aWDaXeC-4VXIa?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.66.1, 2620:100:6022:1::a27d:4201
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.66.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /sh/raw/oxk6087vnsazr60/AABgsh2rrC79aWDaXeC-4VXIa [following]
# --2020-06-17 19:27:40--  https://www.dropbox.com/sh/raw/oxk6087vnsazr60/AABgsh2rrC79aWDaXeC-4VXIa
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc9a386f66758f56b5d1ee5094da.dl.dropboxusercontent.com/zip_download_get/AdNi7t9gxXGzXJzgSf9_Uj8E93LkrlfwiCDUwq56l-OddQ5BEZnYNXQ6QEwtHwDgf9WWxQ4iskKqTJKcf0nquK8H2oaKogeFVh0C-mEFFAL04A [following]
# ...

# %% [markdown]
# #不同数据集的运行参数

# %%
# !python single_experiment.py --dataset CUB --num_shots 0 --generalized true
# Out:
# ***
# 23
# The current working directory is
# /content
# Project Directory:
# /content
# Data Path
# /content/data
# _____
# /content/data/CUB/res101.mat
# resnet_features 2048
# attributes 312
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# train for reconstruction
# epoch 0 | iter 0	 | loss 7395.
# epoch 0 | iter 50	 | loss 5136.
# epoch 0 | iter 100	 | loss 4447.
# epoch 1 | iter 0	 | loss 4204.
# epoch 1 | iter 50	 | loss 4214.
# epoch 1 | iter 100	 | loss 3757.
# epoch 2 | iter 0	 | loss 3811.
# epoch 2 | iter 50	 | loss 3650.
# epoch 2 | iter 100	 | loss 3637.
# epoch 3 | iter 0	 | loss 3314.
# epoch 3 | iter 50	 | loss 3240.
# epoch 3 | iter 100	 | loss 3261.
# epoch 4 | iter 0	 | loss 3292.
# epoch 4 | iter 50	 | loss 3239.
# epoch 4 | iter 100	 | loss 3087.
# epoch 5 | iter 0	 | loss 3050.
# ...

# %%
# !python single_experiment.py --dataset SUN --num_shots 0 --generalized true
# Out:
# ***
# 21
# The current working directory is
# /content
# Project Directory:
# /content
# Data Path
# /content/data
# _____
# /content/data/SUN/res101.mat
# resnet_features 2048
# attributes 102
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# train for reconstruction
# epoch 0 | iter 0	 | loss 7043.
# epoch 0 | iter 50	 | loss 4586.
# epoch 0 | iter 100	 | loss 4372.
# epoch 0 | iter 150	 | loss 4065.
# epoch 0 | iter 200	 | loss 3526.
# epoch 1 | iter 0	 | loss 4065.
# epoch 1 | iter 50	 | loss 3735.
# epoch 1 | iter 100	 | loss 3816.
# epoch 1 | iter 150	 | loss 3728.
# epoch 1 | iter 200	 | loss 3456.
# epoch 2 | iter 0	 | loss 3786.
# epoch 2 | iter 50	 | loss 3547.
# epoch 2 | iter 100	 | loss 3413.
# epoch 2 | iter 150	 | loss 3732.
# epoch 2 | iter 200	 | loss 3598.
# epoch 3 | iter 0	 | loss 3357.
# ...

# %%
# !python single_experiment.py --dataset AWA1 --num_shots 0 --generalized true
# Out:
# ***
# 33
# The current working directory is
# /content
# Project Directory:
# /content
# Data Path
# /content/data
# _____
# /content/data/AWA1/res101.mat
# resnet_features 2048
# attributes 85
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# train for reconstruction
# epoch 0 | iter 0	 | loss 7200.
# epoch 0 | iter 50	 | loss 4378.
# epoch 0 | iter 100	 | loss 4476.
# epoch 0 | iter 150	 | loss 4020.
# epoch 0 | iter 200	 | loss 3880.
# epoch 0 | iter 250	 | loss 3667.
# epoch 0 | iter 300	 | loss 3536.
# epoch 0 | iter 350	 | loss 3739.
# epoch 1 | iter 0	 | loss 3491.
# epoch 1 | iter 50	 | loss 3400.
# epoch 1 | iter 100	 | loss 3178.
# epoch 1 | iter 150	 | loss 3342.
# epoch 1 | iter 200	 | loss 3316.
# epoch 1 | iter 250	 | loss 3199.
# epoch 1 | iter 300	 | loss 3028.
# epoch 1 | iter 350	 | loss 3275.
# ...

# %%
# !python single_experiment.py --dataset AWA2 --num_shots 0 --generalized true
# Out:
# ***
# 29
# The current working directory is
# /content
# Project Directory:
# /content
# Data Path
# /content/data
# _____
# /content/data/AWA2/res101.mat
# resnet_features 2048
# attributes 85
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# train for reconstruction
# epoch 0 | iter 0	 | loss 6885.
# epoch 0 | iter 50	 | loss 4306.
# epoch 0 | iter 100	 | loss 4071.
# epoch 0 | iter 150	 | loss 3724.
# epoch 0 | iter 200	 | loss 3725.
# epoch 0 | iter 250	 | loss 3503.
# epoch 0 | iter 300	 | loss 3479.
# epoch 0 | iter 350	 | loss 3387.
# epoch 0 | iter 400	 | loss 2988.
# epoch 0 | iter 450	 | loss 3511.
# epoch 1 | iter 0	 | loss 3175.
# epoch 1 | iter 50	 | loss 3193.
# epoch 1 | iter 100	 | loss 3078.
# epoch 1 | iter 150	 | loss 3241.
# epoch 1 | iter 200	 | loss 2992.
# epoch 1 | iter 250	 | loss 3130.
# ...
